# %%
#ライブラリをインポート
import os #OSに依存する様々な機能を利用するためのモジュール(ファイルやディレクトリ操作など)
import re #正規表現を利用するためのモジュール
import csv  #csvファイルを扱うためのモジュール
import math #数学的計算のためのモジュール
import matplotlib.pyplot as plt #グラフ描画のためのモジュール
import numpy as np  #多次元配列計算のためのモジュール
import pandas as pd #データフレームを扱うためのモジュール
from scipy import signal  #信号処理のためのモジュール
from scipy.stats import skew, kurtosis  #歪度と尖度を調べるためのモジュール
from sklearn.model_selection import train_test_split  #データをトレーニング用とテスト用に分けるためのモジュール
from sklearn import preprocessing #データを正規化するためのモジュール
from sklearn.preprocessing import StandardScaler  #データを標準化するためのモジュール
from sklearn.preprocessing import LabelEncoder  #カテゴリ変数を数値化するためのモジュール
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error, r2_score #機械学習モデルの性能評価のためのモジュール
import tensorflow as tf #TensorFlow(Googleが開発したオープンソースの機械学習フレームワーク)
from tensorflow import keras  #TensorFlow用のニューラルネットワークライブラリAPI
from tensorflow.keras import layers #ニューラルネットワークのレイヤーを定義するためのモジュール
from keras.utils import plot_model  #モデルをプロットするためのモジュール

# %%
#Google colab用
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#よく使うgit command

#google colabと揃える
#git fetch origin main
#git reset --hard origin/main

# %%
#定数を定義
BINS = 4000  #ヒストグラムのビンの数
EPSILON = .00001  #スムージングパラメータ
UPPER_LIMIT = 1.1 #静止区間の上限
LOWER_LIMIT = 0.9 #静止区間の加減
STATIONARY_INTERVALS = 5  #静止区間除去のサンプルの間隔(静止区間が何サンプル連続したら除去するか)
TRAIN_SIZE = 0.8  #機械学習のトレーニングデータの割合
N_ESTIMATORS = 100  #決定木の数

# %%
#ディレクトリ内のAMWS020のデータセットのファイル名と周波数を取得する関数
def get_Hz_and_filename(path: str) -> list[int, str]:
    filename = os.listdir(path) #引数のパスのディレクトリの中のファイル名一覧を取得
    Hz_and_filename=[]  #ファイル名と周波数を格納するリストを宣言

    for file in filename:
        Hz = re.search(r'\d+', file)    #正規表現を用いてファイル名の中で一番最初に出てくる数字(周波数)を取得
        if Hz:  #数字の入っていないファイル名があるとエラーを吐くので、このif文でチェックする
            Hz_and_filename.append([int(Hz.group(0)), file])    #ファイル名と周波数を格納

    return Hz_and_filename

# %%
#ファイル名と周波数を分けて出力する関数
def divide_Hz_and_filename(Hz_and_filename: list[int, str]) -> tuple[list[int], list[str]]:
    Hz = []
    filename = []
    for row in Hz_and_filename:
      Hz.append(row[0])
      filename.append(row[1])

    return Hz, filename

# %%
#加速度データのCSVファイルから3軸加速度を取得する関数
def get_acceleration(filename: str) -> tuple[list[float], list[float], list[float]]:
    AccX, AccY, AccZ = [], [], []
    with open(filename) as f:
        reader = csv.reader(f)
        for row in reader:
            AccX.append(float(row[2]))
            AccY.append(float(row[3]))
            AccZ.append(float(row[4]))

    return AccX, AccY, AccZ

# %%
#静止区間を除去する関数
def acc_to_remove_stationary_intervals(AccX: list[float], AccY: list[float], AccZ: list[float]) -> list[float]:
    #各軸の加速度の平均を求める
    AvgAccX = sum(AccX) / len(AccX)
    AvgAccY = sum(AccY) / len(AccY)
    AvgAccZ = sum(AccZ) / len(AccZ)

    AvgResultantAcc = math.sqrt(AvgAccX ** 2 + AvgAccY ** 2 + AvgAccZ ** 2) #重力加速度の推定値=合成加速度の平均を求める

    ResultantAcc = [math.sqrt(x ** 2 + y ** 2 + z ** 2) for x, y, z in zip(AccX, AccY, AccZ)]   #各時刻の合成加速度を求める

    #各時刻の合成加速度から静止区間(重力加速度の推定値に近い値が一定以上以上連続している区間)を除去する
    i = 0 #ループ変数
    counter = 0 #静止区間がSTATIONARY_INTERVALS分続いているかをカウントする変数
    while i < len(ResultantAcc):
        if AvgResultantAcc * LOWER_LIMIT < ResultantAcc[i] < AvgResultantAcc * UPPER_LIMIT:   #平均のLOWER_LIMIT倍~UPPER_LIMIT倍の範囲を調べる
            counter += 1    #範囲内ならカウントを増やす
            if counter == STATIONARY_INTERVALS: #カウントがSTATIONARY_INTERVALSに達したらその区間を削除
                del ResultantAcc[i+1-STATIONARY_INTERVALS:i+1]    #スライスでは選択範囲の開始位置startと終了位置stopを[start:stop]のように書くとstart <= x < stopの範囲が選択される #start番目の値は含まれるがstop番目の値は含まれない
                counter = 0 #カウンターをリセット
                i -= STATIONARY_INTERVALS   #削除した分インデックスがズレるので補正する
        else:
            counter = 0 #カウンターをリセット
        i += 1

    return ResultantAcc  #静止区間を除去した後のリストを返す

# %%
#連続する2サンプルの差分を取る関数
def calculate_differences_of_acceleration(ResultantAcc: list[float]) -> list[float]:
    DifferenceAcc = [math.fabs(ResultantAcc[i + 1] * 100000 - ResultantAcc[i] * 100000) for i in range(len(ResultantAcc) - 1)]  #100000倍して誤差を取る
    return DifferenceAcc

# %%
#入力された加速度の差分のリストからヒストグラムを作る関数（ビンの範囲が各加速度の差分データの最小値〜最大値）
def create_histogram2(DifferenceAcc_list: list[float]) -> np.histogram:
    DifferenceAcc_hist = np.zeros((len(DifferenceAcc_list), BINS), dtype=float)
    for i in range(len(DifferenceAcc_list)):
        min_value = min(DifferenceAcc_list[i])
        max_value = max(DifferenceAcc_list[i])
        #DifferenceAcc_hist[i], _ = np.histogram(DifferenceAcc_list[i], bins=BINS, range=(min_value, max_value)) #ヒストグラムを作成し、同じ数のビンで区切る
        DifferenceAcc_hist[i], _ = np.histogram(DifferenceAcc_list[i], bins=BINS, density=True) #ヒストグラムを作成し、同じ数のビンで区切る
    return DifferenceAcc_hist

# %%
#各加速度データをダウンサンプリングする関数
def resampling_Acc(originHz: int, newHz: int, AccX: list[float], AccY: list[float], AccZ: list[float], Hz: np.array) -> tuple[list[float], list[float], list[float], np.array]:
    i = 0   #カウンター変数

    while (Hz[i] == originHz):
        originlen = len(AccX[i])    #元々のデータの長さ
        sampling_factor = int(originlen * (newHz/originHz)) #ダウンサンプリングした後のデータの長さ
        newAccX = signal.resample(AccX[i], sampling_factor)    #データをダウンサンプリング
        newAccY = signal.resample(AccY[i], sampling_factor)    #データをダウンサンプリング
        newAccZ = signal.resample(AccZ[i], sampling_factor)    #データをダウンサンプリング
        AccX.append(newAccX)   #ダウンサンプリングデータを加速度データに追加
        AccY.append(newAccY)   #ダウンサンプリングデータを加速度データに追加
        AccZ.append(newAccZ)   #ダウンサンプリングデータを加速度データに追加
        Hz = np.append(Hz, newHz)   #ダウンサンプリングレートを追加
        i += 1

    return AccX, AccY, AccZ, Hz

# %%
path = "/content/drive/MyDrive/my_walk_data(100Hz15minutes)/"  #Google colab用
#path = "my_walk_data(100Hz15minutes)/"  #local用

# %%
#GPUを使うためのコマンド
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
#一連の流れ
Hz_and_filename = get_Hz_and_filename(path)
Hz_and_filename.sort(reverse=True)  #周波数の大きい順にソート
Hz, filename = divide_Hz_and_filename(Hz_and_filename)
Hz = np.array(Hz)

#使う変数を宣言
readAccX, readAccY, readAccZ = [], [], []   #データ読み込む用
AccX, AccY, AccZ = [], [], []
ResultantAcc = []
DifferenceAcc_list = []

#各データセットからデータを読み込み二次元配列に格納
for i in filename:
    readAccX, readAccY, readAccZ = get_acceleration(path+i)
    AccX.append(readAccX), AccY.append(readAccY), AccZ.append(readAccZ)

#各加速度データをダウンサンプリング
for i in range(9, 1, -1):
    AccX, AccY, AccZ, Hz = resampling_Acc(100, i * 10, AccX, AccY, AccZ, Hz)

#静止区間を除去
for i in range(len(Hz)):
    ResultantAcc.append(acc_to_remove_stationary_intervals(AccX[i], AccY[i], AccZ[i]))

# %%
#ヒストグラム作成
for i in range(len(ResultantAcc)):
    DifferenceAcc_list.append(calculate_differences_of_acceleration(ResultantAcc[i]))
DifferenceAcc_hist = create_histogram2(DifferenceAcc_list)

# %%
sum(DifferenceAcc_hist[3])
# Out:
# 4.334683965589198e-07

# %%
#ヒストグラムの度数を揃える
for i in range(len(DifferenceAcc_list)):
  for j in range(BINS):
      DifferenceAcc_hist[i][j] = DifferenceAcc_hist[i][j] / sum(DifferenceAcc_hist[i])

# %%
#グラフを表示する領域を，figオブジェクトとして作成。
fig = plt.figure(figsize = (9,6))
xl1 = "acceleration (0.1mG)"
yl1 = "frequency"

#グラフを描画するsubplot領域を作成。
ax1 = fig.add_subplot(3, 1, 1)
ax2 = fig.add_subplot(3, 1, 2)
ax3 = fig.add_subplot(3, 1, 3)

#各subplot領域にデータを渡す
ax1.hist(ResultantAcc[0], bins=BINS,density=True, range = (0, 40000), label="100 Hz")
ax2.hist(ResultantAcc[125], bins=BINS, density=True, range = (0, 40000), label="50 Hz")
ax3.hist(ResultantAcc[200], bins=BINS,density=True, range = (0, 40000), label="20 Hz")

#各subplotにxラベルを追加
ax1.set_xlabel(xl1)
ax2.set_xlabel(xl1)
ax3.set_xlabel(xl1)

#各subplotにyラベルを追加
ax1.set_ylabel(yl1)
ax2.set_ylabel(yl1)
ax3.set_ylabel(yl1)

# 凡例表示
ax1.legend(loc = 'upper right')
ax2.legend(loc = 'upper right')
ax3.legend(loc = 'upper right')

plt.show()

# %%
#入力データの標準化
scaler = StandardScaler()
# Fit the scaler to x_train
scaler.fit(DifferenceAcc_hist)
# Use the scaler to transform x_train and x_test
DifferenceAcc_hist = scaler.transform(DifferenceAcc_hist)

# %%
#トレーニングデータとテストデータの分割
x_train, x_test, y_train, y_test = train_test_split(DifferenceAcc_hist, Hz, train_size = TRAIN_SIZE, shuffle = True)

# %%
#transformer regression
#各種パラメータ
NUM_HEADS = 8
KEY_DIM = int(BINS/NUM_HEADS)
DROPOUT = 0.1
N = 1

# Define the input shape
input_shape = BINS
output_shape = 1

#形を定義(このモジュールは行列でないとダメっぽい)
inputs_encoder = layers.Input(shape=input_shape)
inputs_decoder = layers.Input(shape=output_shape)

# %%
#Encoderに対する入力の形状
x_encoder = layers.Reshape((10, int(BINS/10)))(inputs_encoder)

# %%
#Transformer Encoder Layer(BERT)
for i in range(N):
      #Multi-Head-Attention Layer
      attention_encoder = layers.MultiHeadAttention(num_heads=NUM_HEADS, key_dim=KEY_DIM, use_bias=True)(x_encoder, x_encoder, x_encoder)

      #Dropout Layer
      attention_encoder = layers.Dropout(rate=DROPOUT)(attention_encoder)
      #Add & Norm Layer
      attention_encoder = layers.LayerNormalization()(x_encoder + attention_encoder)

      #Feed-Forward-Network
      ffn_encoder = layers.Dense(int(BINS/10) * 4, use_bias=True, activation="relu")(attention_encoder)
      ffn_encoder = layers.Dense(int(BINS/10), use_bias=True)(ffn_encoder)

      #Dropout Layer
      ffn_encoder = layers.Dropout(rate=DROPOUT)(ffn_encoder)
      #Add & Norm Layer
      x_encoder = layers.LayerNormalization()(attention_encoder + ffn_encoder)

# %%
#only Encoder(Dense追加BERT)
x = layers.Flatten()(x_encoder)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.1)(x)
x = layers.Dense(64, activation="relu")(x)
x = layers.Dropout(0.1)(x)
outputs = layers.Dense(1, activation="relu")(x)
model = keras.Model(inputs=inputs_encoder, outputs=outputs)

# %%
# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.mean_squared_error,
    metrics=[keras.metrics.mean_squared_error],
)

# %%
#モデルの画像を出力
plot_model(model, show_shapes=True, show_layer_names=False)

# %%
sum(DifferenceAcc_hist[2])
# Out:
# -1153.1288998718098

# %%
mae = []
mse = []
r2 = []
var = []

# %%
for i in range(10):
  #only Encoder Transformer 試行用
  x_train, x_test, y_train, y_test = train_test_split(DifferenceAcc_hist, Hz, train_size = TRAIN_SIZE, shuffle = True)
  history = model.fit(x_train, y_train, batch_size=32, epochs=300, shuffle=True, validation_split=0.2)
  y_pred = tf.cast(tf.clip_by_value(model.predict(x_test), 20, 100), tf.int32)
  mae.append(mean_absolute_error(y_pred, y_test))
  mse.append(mean_squared_error(y_pred, y_test))
  r2.append(r2_score(y_pred, y_test))
  #aa = Hz.reshape(len(Hz),1)
  #diff = y_pred - aa
  #var.append(np.var(diff))
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Epoch 206/300
# 5/5 [==============================] - 0s 25ms/step - loss: 9.7702 - mean_squared_error: 9.7702 - val_loss: 12.8802 - val_mean_squared_error: 12.8802
# Epoch 207/300
# 5/5 [==============================] - 0s 23ms/step - loss: 14.9365 - mean_squared_error: 14.9365 - val_loss: 6.5776 - val_mean_squared_error: 6.5776
# Epoch 208/300
# 5/5 [==============================] - 0s 24ms/step - loss: 12
# Epoch 5/300
# 5/5 [==============================] - 0s 34ms/step - loss: 13.2610 - mean_squared_error: 13.2610 - val_loss: 8.6480 - val_mean_squared_error: 8.6480
# Epoch 6/300
# 5/5 [==============================] - 0s 32ms/step - loss: 15.7263 - mean_squared_error: 15.7263 - val_loss: 8.0922 - val_mean_squared_error: 8.0922
# Epoch 7/300
# 5/5 [==============================] - 0s 35ms/step - loss: 10.8227 - mean_squared_error: 10.8227 - val_loss: 15.5845 - val_mean_squared_error: 15.5845
# Epoch 8/300
# 5/5 [==============================] - 0s 32ms/step - loss: 12.6238 - mean_squared_error: 12.6238 - val_loss: 4.7915 - val_mean_squared_error: 4.7915
# Epoch 9/300
# 5/5 [==============================] - 0s 33ms/step - loss: 12.2468 - mean_squared_error: 12.2468 - val_loss: 4.3704 - val_mean_squared_error: 4.3704
# Epoch 10/300
# 5/5 [==============================] - 0s 28ms/step - loss: 17.8788 - mean_squared_error: 17.8788 - val_loss: 11.5933 - val_mean_squared_error: 11.5933
# Epoch 11/300
# 5/5 [==============================] - 0s 35ms/step - loss: 11.4026 - mean_squared_error: 11.4026 - val_loss: 6.2089 - val_mean_squared_error: 6.2089
# Epoch 12/300
# 5/5 [==============================] - 0s 33ms/step - loss: 11.9974 - mean_squared_error: 11.9974 - val_loss: 11.5980 - val_mean_squared_error: 11.5980
# Epoch 13/300
# 5/5 [==============================] - 0s 30ms/step - loss: 12.7801 - mean_squared_error: 12.7801 - val_loss: 6.3155 - val_mean_squared_error: 6.3155
# Epoch 14/300
# 5/5 [==============================] - 0s 28ms/step - loss: 15.0115 - mean_squared_error: 15.0115 - val_loss: 14.5267 - val_mean_squared_error: 14.5267
# Epoch 15/300
# 5/5 [==============================] - 0s 29ms/step - loss: 15.8356 - mean_squared_error: 15.8356 - val_loss: 8.2259 - val_mean_squared_error: 8.2259
# Epoch 16/300
# 5/5 [==============================] - 0s 27ms/step - loss: 12.6585 - mean_squared_error: 12.6585 - val_loss: 3.8060 - val_mean_squared_error: 3.8060
# Epoch 17/300
# 5/5 [==============================] - 0s 30ms/step - loss: 14.2005 - mean_squared_error: 14.2005 - val_loss: 8.8214 - val_mean_squared_error: 8.8214
# Epoch 18/300
# 5/5 [==============================] - 0s 30ms/step - loss: 10.7880 - mean_squared_error: 10.7880 - val_loss: 10.8794 - val_mean_squared_error: 10.8794
# Epoch 19/300
# 5/5 [==============================] - 0s 29ms/step - loss: 9.9472 - mean_squared_error: 9.9472 - val_loss: 6.0383 - val_mean_squared_error: 6.0383
# Epoch 20/300
# 5/5 [==============================] - 0s 29ms/step - loss: 12.5932 - mean_squared_error: 12.5932 - val_loss: 11.6900 - val_mean_squared_error: 11.6900
# Epoch 21/300
# 5/5 [==============================] - 0s 31ms/step - loss: 11.7678 - mean_squared_error: 11.7678 - val_loss: 7.9363 - val_mean_squared_error: 7.9363
# Epoch 22/300
# 5/5 [==============================] - 0s 31ms/step - loss: 16.8160 - mean_squared_error: 16.8160 - val_loss: 7.4652 - val_mean_squared_error: 7.4652
# Epoch 23/300
# 5/5 [==============================] - 0s 32ms/step - loss: 13.5231 - mean_squared_error: 13.5231 - val_loss: 17.2390 - val_mean_squared_error: 17.2390
300
# 5/5 [==============================] - 0s 25ms/step - loss: 15.6465 - mean_squared_error: 15.6465 - val_loss: 20.9664 - val_mean_squared_error: 20.9664
# Epoch 179/300
# 5/5 [==============================] - 0s 20ms/step - loss: 13.3420 - mean_squared_error: 13.3420 - val_loss: 8.8902 - val_mean_squared_error: 8.8902
# Epoch 180/300
# 5/5 [==============================] - 0s 27ms/step - loss: 15.6926 - mean_squared_error: 15.6926 - val_loss: 19.9000 - val_mean_squared_error: 19.9000
# Epoch 181/300
# 5/5 [==============================] - 0s 26ms/step - loss: 13.4900 - mean_squared_error: 13.4900 - val_loss: 11.1900 - val_mean_squared_error: 11.1900
# Epoch 182/300
# 5/5 [==============================] - 0s 27ms/step - loss: 12.8116 - mean_squared_error: 12.8116 - val_loss: 20.6983 - val_mean_squared_error: 20.6983
# Epoch 183/300
# 5/5 [==============================] - 0s 26ms/step - loss: 12.9550 - mean_squared_error: 12.9550 - val_loss: 10.2447 - val_mean_squared_error: 10.2447
# Epoch 184/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.2166 - mean_squared_error: 14.2166 - val_loss: 8.4974 - val_mean_squared_error: 8.4974
# Epoch 185/300
# 5/5 [==============================] - 0s 20ms/step - loss: 15.7405 - mean_squared_error: 15.7405 - val_loss: 23.3449 - val_mean_squared_error: 23.3449
# Epoch 186/300
# 5/5 [==============================] - 0s 26ms/step - loss: 10.2223 - mean_squared_error: 10.2223 - val_loss: 10.0311 - val_mean_squared_error: 10.0311
# Epoch 187/300
# 5/5 [==============================] - 0s 29ms/step - loss: 13.6103 - mean_squared_error: 13.6103 - val_loss: 10.8314 - val_mean_squared_error: 10.8314
# Epoch 188/300
# 5/5 [==============================] - 0s 25ms/step - loss: 9.2535 - mean_squared_error: 9.2535 - val_loss: 19.2040 - val_mean_squared_error: 19.2040
# Epoch 189/300
# 5/5 [==============================] - 0s 23ms/step - loss: 10.7850 - mean_squared_error: 10.7850 - val_loss: 7.0348 - val_mean_squared_error: 7.0348
# Epoch 190/300
# 5/5 [==============================] - 0s 20ms/step - loss: 13.0610 - mean_squared_error: 13.0610 - val_loss: 10.3847 - val_mean_squared_error: 10.3847
# Epoch 191/300
# 5/5 [==============================] - 0s 24ms/step - loss: 11.3860 - mean_squared_error: 11.3860 - val_loss: 10.2340 - val_mean_squared_error: 10.2340
# Epoch 192/300
# 5/5 [==============================] - 0s 24ms/step - loss: 12.3291 - mean_squared_error: 12.3291 - val_loss: 10.6952 - val_mean_squared_error: 10.6952
# Epoch 193/300
# 5/5 [==============================] - 0s 27ms/step - loss: 12.0983 - mean_squared_error: 12.0983 - val_loss: 8.8223 - val_mean_squared_error: 8.8223
# Epoch 194/300
# 5/5 [==============================] - 0s 20ms/step - loss: 20.7452 - mean_squared_error: 20.7452 - val_loss: 13.5449 - val_mean_squared_error: 13.5449
# Epoch 195/300
# 5/5 [==============================] - 0s 28ms/step - loss: 12.3044 - mean_squared_error: 12.3044 - val_loss: 19.1692 - val_mean_squared_error: 19.1692
# Epoch 196/300
# 5/5 [==============================] - 0s 26ms/step - loss: 12.7202 - mean_squared_error: 12.7202 - val_loss: 9.4797 - val_mean_squared_error: 9.4797
# Epoch 197/300
# ...
# Epoch 204/300
# 5/5 [==============================] - 0s 26ms/step - loss: 13.0171 - mean_squared_error: 13.0171 - val_loss: 6.7459 - val_mean_squared_error: 6.7459
# Epoch 205/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.0711 - mean_squared_error: 14.0711 - val_loss: 10.4433 - val_mean_squared_error: 10.4433
# Epoch 206/300
# 5/5 [==============================] - 0s 25ms/step - loss: 14.7937 - mean_squared_error: 14.7937 - val_loss: 2.8744 - val_mean_squared_error: 2.8744
# Epoch 207/300
# 5/5 [==============================] - 0s 27ms/step - loss: 13.0277 - mean_squared_error: 13.0277 - val_loss: 19.7053 - val_mean_squared_error: 19.7053
# Epoch 208/300
# 5/5 [==============================] - 0s 28ms/step - loss: 12.8774 - mean_squared_error: 12.8774 - val_loss: 3.1799 - val_mean_squared_error: 3.1799
# Epoch 209/300
# 5/5 [==============================] - 0s 25ms/step - loss: 14.6698 - mean_squared_error: 14.6698 - val_loss: 7.1925 - val_mean_squared_error: 7.1925
# Epoch 210/300
# 5/5 [==============================] - 0s 27ms/step - loss: 8.8428 - mean_squared_error: 8.8428 - val_loss: 5.2467 - val_mean_squared_error: 5.2467
# Epoch 211/300
# 5/5 [==============================] - 0s 26ms/step - loss: 11.9646 - mean_squared_error: 11.9646 - val_loss: 4.2398 - val_mean_squared_error: 4.2398
# Epoch 212/300
# 5/5 [==============================] - 0s 28ms/step - loss: 17.3095 - mean_squared_error: 17.3095 - val_loss: 16.1748 - val_mean_squared_error: 16.1748
# Epoch 213/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.5123 - mean_squared_error: 14.5123 - val_loss: 2.6049 - val_mean_squared_error: 2.6049
# Epoch 214/300
# 5/5 [==============================] - 0s 28ms/step - loss: 13.2276 - mean_squared_error: 13.2276 - val_loss: 12.3489 - val_mean_squared_error: 12.3489
# Epoch 215/300
# 5/5 [==============================] - 0s 26ms/step - loss: 11.6447 - mean_squared_error: 11.6447 - val_loss: 7.9478 - val_mean_squared_error: 7.9478
# Epoch 216/300
# 5/5 [==============================] - 0s 25ms/step - loss: 16.4275 - mean_squared_error: 16.4275 - val_loss: 2.8078 - val_mean_squared_error: 2.8078
# Epoch 217/300
# 5/5 [==============================] - 0s 30ms/step - loss: 12.7256 - mean_squared_error: 12.7256 - val_loss: 8.7695 - val_mean_squared_error: 8.7695
# Epoch 218/300
# 5/5 [==============================] - 0s 29ms/step - loss: 8.1492 - mean_squared_error: 8.1492 - val_loss: 6.8035 - val_mean_squared_error: 6.8035
# Epoch 219/300
# 5/5 [==============================] - 0s 28ms/step - loss: 11.4844 - mean_squared_error: 11.4844 - val_loss: 5.5120 - val_mean_squared_error: 5.5120
# Epoch 220/300
# 5/5 [==============================] - 0s 31ms/step - loss: 15.6173 - mean_squared_error: 15.6173 - val_loss: 4.3556 - val_mean_squared_error: 4.3556
# Epoch 221/300
# 5/5 [==============================] - 0s 28ms/step - loss: 16.2158 - mean_squared_error: 16.2158 - val_loss: 12.3129 - val_mean_squared_error: 12.3129
# Epoch 222/300
# 5/5 [==============================] - 0s 27ms/step - loss: 14.6439 - mean_squared_error: 14.6439 - val_loss: 2.6989 - val_mean_squared_error: 2.6989
# Epoch 223/300
# 5/5 [==============================] - 0s 26ms/step - loss: 13.5012 - mean_squared_error: 13.5012 - val_loss: 6.9797 - val_mean_squared_error: 6.9797
# Epoch 224/300
# 5/5 [==============================] - 0s 25ms/step - loss: 14.9452 - mean_squared_error: 14.9452 - val_loss: 4.3153 - val_mean_squared_error: 4.3153
# Epoch 225/300
# 5/5 [==============================] - 0s 27ms/step - loss: 15.4595 - mean_squared_error: 15.4595 - val_loss: 5.3829 - val_mean_squared_error: 5.3829
# Epoch 226/300
# 5/5 [==============================] - 0s 28ms/step - loss: 10.2081 - mean_squared_error: 10.2081 - val_loss: 11.0062 - val_mean_squared_error: 11.0062
# Epoch 227/300
# 5/5 [==============================] - 0s 29ms/step - loss: 14.5371 - mean_squared_error: 14.5371 - val_loss: 8.0443 - val_mean_squared_error: 8.0443
# Epoch 228/300
# 5/5 [==============================] - 0s 26ms/step - loss: 10.6728 - mean_squared_error: 10.6728 - val_loss: 6.2111 - val_mean_squared_error: 6.2111
# Epoch 229/300
# 5/5 [==============================] - 0s 28ms/step - loss: 10.8959 - mean_squared_error: 10.8959 - val_loss: 6.4964 - val_mean_squared_error: 6.4964
# Epoch 230/300
# 5/5 [==============================] - 0s 25ms/step - loss: 10.9676 - mean_squared_error: 10.9676 - val_loss: 4.5497 - val_mean_squared_error: 4.5497
# Epoch 231/300
# 5/5 [==============================] - 0s 28ms/step - loss: 13.7784 - mean_squared_error: 13.7784 - val_loss: 3.1231 - val_mean_squared_error: 3.1231
# Epoch 232/300
# 5/5 [==============================] - 0s 27ms/step - loss: 11.1789 - mean_squared_error: 11.1789 - val_loss: 6.7268 - val_mean_squared_error: 6.7268
# Epoch 233/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.7894 - mean_squared_error: 14.7894 - val_loss: 4.8170 - val_mean_squared_error: 4.8170
# Epoch 234/300
# 5/5 [==============================] - 0s 27ms/step - loss: 10.3772 - mean_squared_error: 10.3772 - val_loss: 11.9050 - val_mean_squared_error: 11.9050
# Epoch 235/300
# 5/5 [==============================] - 0s 26ms/step - loss: 15.7165 - mean_squared_error: 15.7165 - val_loss: 3.9052 - val_mean_squared_error: 3.9052
# Epoch 236/300
# 5/5 [==============================] - 0s 26ms/step - loss: 16.6264 - mean_squared_error: 16.6264 - val_loss: 8.7336 - val_mean_squared_error: 8.7336
# Epoch 237/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.1995 - mean_squared_error: 14.1995 - val_loss: 3.9546 - val_mean_squared_error: 3.9546
# Epoch 238/300
# 5/5 [==============================] - 0s 25ms/step - loss: 10.1648 - mean_squared_error: 10.1648 - val_loss: 9.4965 - val_mean_squared_error: 9.4965
# Epoch 239/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.1940 - mean_squared_error: 14.1940 - val_loss: 3.8670 - val_mean_squared_error: 3.8670
# Epoch 240/300
# 5/5 [==============================] - 0s 31ms/step - loss: 10.8711 - mean_squared_error: 10.8711 - val_loss: 6.3807 - val_mean_squared_error: 6.3807
# Epoch 241/300
# 5/5 [==============================] - 0s 29ms/step - loss: 9.4923 - mean_squared_error: 9.4923 - val_loss: 13.8236 - val_mean_squared_error: 13.8236
# Epoch 242/300
# 5/5 [==============================] - 0s 25ms/step - loss: 10.2803 - mean_squared_error: 10.2803 - val_loss: 6.8484 - val_mean_squared_error: 6.8484
# Epoch 243/300
# 5/5 [==============================] - 0s 28ms/step - loss: 11.0451 - mean_squared_error: 11.0451 - val_loss: 6.4423 - val_mean_squared_error: 6.4423
# Epoch 244/300
# 5/5 [==============================] - 0s 25ms/step - loss: 12.2571 - mean_squared_error: 12.2571 - val_loss: 5.9033 - val_mean_squared_error: 5.9033
# Epoch 245/300
# 5/5 [==============================] - 0s 27ms/step - loss: 10.3522 - mean_squared_error: 10.3522 - val_loss: 2.5116 - val_mean_squared_error: 2.5116
# Epoch 246/300
# 5/5 [==============================] - 0s 26ms/step - loss: 8.5249 - mean_squared_error: 8.5249 - val_loss: 8.1249 - val_mean_squared_error: 8.1249
# Epoch 247/300
# 5/5 [==============================] - 0s 31ms/step - loss: 9.6505 - mean_squared_error: 9.6505 - val_loss: 4.6272 - val_mean_squared_error: 4.6272
# Epoch 248/300
# 5/5 [==============================] - 0s 26ms/step - loss: 11.3977 - mean_squared_error: 11.3977 - val_loss: 2.0148 - val_mean_squared_error: 2.0148
# Epoch 249/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.2782 - mean_squared_error: 14.2782 - val_loss: 4.8606 - val_mean_squared_error: 4.8606
# Epoch 250/300
# 5/5 [==============================] - 0s 26ms/step - loss: 12.3837 - mean_squared_error: 12.3837 - val_loss: 8.9223 - val_mean_squared_error: 8.9223
# Epoch 251/300
# 5/5 [==============================] - 0s 25ms/step - loss: 16.1980 - mean_squared_error: 16.1980 - val_loss: 2.4779 - val_mean_squared_error: 2.4779
# Epoch 252/300
# 5/5 [==============================] - 0s 24ms/step - loss: 14.5564 - mean_squared_error: 14.5564 - val_loss: 8.7268 - val_mean_squared_error: 8.7268
# Epoch 253/300
# 5/5 [==============================] - 0s 26ms/step - loss: 15.2096 - mean_squared_error: 15.2096 - val_loss: 5.0975 - val_mean_squared_error: 5.0975
# Epoch 254/300
# 5/5 [==============================] - 0s 26ms/step - loss: 11.9193 - mean_squared_error: 11.9193 - val_loss: 5.4411 - val_mean_squared_error: 5.4411
# Epoch 255/300
# 5/5 [==============================] - 0s 24ms/step - loss: 12.7282 - mean_squared_error: 12.7282 - val_loss: 8.6395 - val_mean_squared_error: 8.6395
# Epoch 256/300
# 5/5 [==============================] - 0s 25ms/step - loss: 9.3282 - mean_squared_error: 9.3282 - val_loss: 3.4909 - val_mean_squared_error: 3.4909
# Epoch 257/300
# 5/5 [==============================] - 0s 30ms/step - loss: 9.3888 - mean_squared_error: 9.3888 - val_loss: 4.3308 - val_mean_squared_error: 4.3308
# Epoch 258/300
# 5/5 [==============================] - 0s 28ms/step - loss: 10.8024 - mean_squared_error: 10.8024 - val_loss: 4.8099 - val_mean_squared_error: 4.8099
# Epoch 259/300
# 5/5 [==============================] - 0s 28ms/step - loss: 15.6084 - mean_squared_error: 15.6084 - val_loss: 4.9231 - val_mean_squared_error: 4.9231
# Epoch 260/300
# 5/5 [==============================] - 0s 27ms/step - loss: 12.7070 - mean_squared_error: 12.7070 - val_loss: 10.1564 - val_mean_squared_error: 10.1564
# Epoch 261/300
# 5/5 [==============================] - 0s 28ms/step - loss: 11.4706 - mean_squared_error: 11.4706 - val_loss: 3.8089 - val_mean_squared_error: 3.8089
# Epoch 262/300
# 5/5 [==============================] - 0s 32ms/step - loss: 18.8320 - mean_squared_error: 18.8320 - val_loss: 6.5062 - val_mean_squared_error: 6.5062
# Epoch 263/300
# 5/5 [==============================] - 0s 39ms/step - loss: 10.4031 - mean_squared_error: 10.4031 - val_loss: 8.9648 - val_mean_squared_error: 8.9648
# Epoch 264/300
# 5/5 [==============================] - 0s 35ms/step - loss: 14.5746 - mean_squared_error: 14.5746 - val_loss: 2.0009 - val_mean_squared_error: 2.0009
# Epoch 265/300
# 5/5 [==============================] - 0s 33ms/step - loss: 14.3346 - mean_squared_error: 14.3346 - val_loss: 19.0934 - val_mean_squared_error: 19.0934
# Epoch 266/300
# 5/5 [==============================] - 0s 38ms/step - loss: 14.6365 - mean_squared_error: 14.6365 - val_loss: 2.2825 - val_mean_squared_error: 2.2825
# Epoch 267/300
# 5/5 [==============================] - 0s 37ms/step - loss: 14.0329 - mean_squared_error: 14.0329 - val_loss: 8.0348 - val_mean_squared_error: 8.0348
# Epoch 268/300
# 5/5 [==============================] - 0s 34ms/step - loss: 22.8349 - mean_squared_error: 22.8349 - val_loss: 2.9512 - val_mean_squared_error: 2.9512
# Epoch 269/300
# 5/5 [==============================] - 0s 37ms/step - loss: 15.8609 - mean_squared_error: 15.8609 - val_loss: 8.0591 - val_mean_squared_error: 8.0591
# Epoch 270/300
# Epoch 288/300
# 5/5 [==============================] - 0s 34ms/step - loss: 10.3449 - mean_squared_error: 10.3449 - val_loss: 5.2175 - val_mean_squared_error: 5.2175
# Epoch 289/300
# 5/5 [==============================] - 0s 41ms/step - loss: 12.5139 - mean_squared_error: 12.5139 - val_loss: 10.8962 - val_mean_squared_error: 10.8962
# Epoch 290/300
# 5/5 [==============================] - 0s 42ms/step - loss: 12.1637 - mean_squared_error: 12.1637 - val_loss: 2.7994 - val_mean_squared_error: 2.7994
# Epoch 291/300
# 5/5 [==============================] - 0s 41ms/step - loss: 8.4488 - mean_squared_error: 8.4488 - val_loss: 7.5787 - val_mean_squared_error: 7.5787
# Epoch 292/300
# 5/5 [==============================] - 0s 39ms/step - loss: 15.6596 - mean_squared_error: 15.6596 - val_loss: 4.3827 - val_mean_squared_error: 4.3827
# Epoch 293/300
# 5/5 [==============================] - 0s 32ms/step - loss: 11.9473 - mean_squared_error: 11.9473 - val_loss: 4.9718 - val_mean_squared_error: 4.9718
# Epoch 294/300
# 5/5 [==============================] - 0s 41ms/step - loss: 11.7401 - mean_squared_error: 11.7401 - val_loss: 7.8378 - val_mean_squared_error: 7.8378
# Epoch 295/300
# 5/5 [==============================] - 0s 40ms/step - loss: 10.4444 - mean_squared_error: 10.4444 - val_loss: 5.4115 - val_mean_squared_error: 5.4115
# Epoch 296/300
# 5/5 [==============================] - 0s 36ms/step - loss: 9.3221 - mean_squared_error: 9.3221 - val_loss: 1.9800 - val_mean_squared_error: 1.9800
# Epoch 297/300
# 5/5 [==============================] - 0s 34ms/step - loss: 12.0658 - mean_squared_error: 12.0658 - val_loss: 9.1939 - val_mean_squared_error: 9.1939
# Epoch 298/300
# 5/5 [==============================] - 0s 32ms/step - loss: 10.4686 - mean_squared_error: 10.4686 - val_loss: 5.8750 - val_mean_squared_error: 5.8750
# Epoch 299/300
# 5/5 [==============================] - 0s 29ms/step - loss: 11.3663 - mean_squared_error: 11.3663 - val_loss: 5.9086 - val_mean_squared_error: 5.9086
# Epoch 300/300
# 5/5 [==============================] - 0s 31ms/step - loss: 12.4105 - mean_squared_error: 12.4105 - val_loss: 9.2715 - val_mean_squared_error: 9.2715
# 2/2 [==============================] - 0s 11ms/step

# %%
mae
# Out:
# [2.3555555555555556,
#  3.088888888888889,
#  2.7777777777777777,
#  3.422222222222222,
#  3.2222222222222223,
#  3.4,
#  1.8666666666666667,
#  1.9555555555555555,
#  2.577777777777778,
#  2.7777777777777777]

# %%
mse
# Out:
# [10.8,
#  13.622222222222222,
#  10.955555555555556,
#  14.933333333333334,
#  15.622222222222222,
#  28.2,
#  6.088888888888889,
#  5.555555555555555,
#  8.311111111111112,
#  12.466666666666667]

# %%
r2
# Out:
# [0.9822407366805526,
#  0.9772082055417481,
#  0.9809711286089239,
#  0.9703563124193719,
#  0.9751182541642612,
#  0.9523523050787495,
#  0.9901188779917842,
#  0.9891904876291137,
#  0.9862267069308389,
#  0.9792475692240917]
