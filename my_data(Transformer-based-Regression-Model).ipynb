# %%
#ライブラリをインポート
import os #OSに依存する様々な機能を利用するためのモジュール(ファイルやディレクトリ操作など)
import re #正規表現を利用するためのモジュール
import csv  #csvファイルを扱うためのモジュール
import math #数学的計算のためのモジュール
import matplotlib.pyplot as plt #グラフ描画のためのモジュール
import numpy as np  #多次元配列計算のためのモジュール
import pandas as pd #データフレームを扱うためのモジュール
from scipy import signal  #信号処理のためのモジュール
from scipy.stats import skew, kurtosis  #歪度と尖度を調べるためのモジュール
from sklearn.model_selection import train_test_split  #データをトレーニング用とテスト用に分けるためのモジュール
from sklearn import preprocessing #データを正規化するためのモジュール
from sklearn.preprocessing import StandardScaler  #データを標準化するためのモジュール
from sklearn.preprocessing import LabelEncoder  #カテゴリ変数を数値化するためのモジュール
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error, r2_score #機械学習モデルの性能評価のためのモジュール
import tensorflow as tf #TensorFlow(Googleが開発したオープンソースの機械学習フレームワーク)
from tensorflow import keras  #TensorFlow用のニューラルネットワークライブラリAPI
from tensorflow.keras import layers #ニューラルネットワークのレイヤーを定義するためのモジュール
from keras.utils import plot_model  #モデルをプロットするためのモジュール

# %%
#Google colab用
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#よく使うgit command

#google colabと揃える
#git fetch origin main
#git reset --hard origin/main

# %%
#定数を定義
BINS = 4000  #ヒストグラムのビンの数
EPSILON = .00001  #スムージングパラメータ
UPPER_LIMIT = 1.1 #静止区間の上限
LOWER_LIMIT = 0.9 #静止区間の加減
STATIONARY_INTERVALS = 5  #静止区間除去のサンプルの間隔(静止区間が何サンプル連続したら除去するか)
TRAIN_SIZE = 0.8  #機械学習のトレーニングデータの割合
N_ESTIMATORS = 100  #決定木の数

# %%
#ディレクトリ内のAMWS020のデータセットのファイル名と周波数を取得する関数
def get_Hz_and_filename(path: str) -> list[int, str]:
    filename = os.listdir(path) #引数のパスのディレクトリの中のファイル名一覧を取得
    Hz_and_filename=[]  #ファイル名と周波数を格納するリストを宣言

    for file in filename:
        Hz = re.search(r'\d+', file)    #正規表現を用いてファイル名の中で一番最初に出てくる数字(周波数)を取得
        if Hz:  #数字の入っていないファイル名があるとエラーを吐くので、このif文でチェックする
            Hz_and_filename.append([int(Hz.group(0)), file])    #ファイル名と周波数を格納

    return Hz_and_filename

# %%
#ファイル名と周波数を分けて出力する関数
def divide_Hz_and_filename(Hz_and_filename: list[int, str]) -> tuple[list[int], list[str]]:
    Hz = []
    filename = []
    for row in Hz_and_filename:
      Hz.append(row[0])
      filename.append(row[1])

    return Hz, filename

# %%
#加速度データのCSVファイルから3軸加速度を取得する関数
def get_acceleration(filename: str) -> tuple[list[float], list[float], list[float]]:
    AccX, AccY, AccZ = [], [], []
    with open(filename) as f:
        reader = csv.reader(f)
        for row in reader:
            AccX.append(float(row[2]))
            AccY.append(float(row[3]))
            AccZ.append(float(row[4]))

    return AccX, AccY, AccZ

# %%
#静止区間を除去する関数
def acc_to_remove_stationary_intervals(AccX: list[float], AccY: list[float], AccZ: list[float]) -> list[float]:
    #各軸の加速度の平均を求める
    AvgAccX = sum(AccX) / len(AccX)
    AvgAccY = sum(AccY) / len(AccY)
    AvgAccZ = sum(AccZ) / len(AccZ)

    AvgResultantAcc = math.sqrt(AvgAccX ** 2 + AvgAccY ** 2 + AvgAccZ ** 2) #重力加速度の推定値=合成加速度の平均を求める

    ResultantAcc = [math.sqrt(x ** 2 + y ** 2 + z ** 2) for x, y, z in zip(AccX, AccY, AccZ)]   #各時刻の合成加速度を求める

    #各時刻の合成加速度から静止区間(重力加速度の推定値に近い値が一定以上以上連続している区間)を除去する
    i = 0 #ループ変数
    counter = 0 #静止区間がSTATIONARY_INTERVALS分続いているかをカウントする変数
    while i < len(ResultantAcc):
        if AvgResultantAcc * LOWER_LIMIT < ResultantAcc[i] < AvgResultantAcc * UPPER_LIMIT:   #平均のLOWER_LIMIT倍~UPPER_LIMIT倍の範囲を調べる
            counter += 1    #範囲内ならカウントを増やす
            if counter == STATIONARY_INTERVALS: #カウントがSTATIONARY_INTERVALSに達したらその区間を削除
                del ResultantAcc[i+1-STATIONARY_INTERVALS:i+1]    #スライスでは選択範囲の開始位置startと終了位置stopを[start:stop]のように書くとstart <= x < stopの範囲が選択される #start番目の値は含まれるがstop番目の値は含まれない
                counter = 0 #カウンターをリセット
                i -= STATIONARY_INTERVALS   #削除した分インデックスがズレるので補正する
        else:
            counter = 0 #カウンターをリセット
        i += 1

    return ResultantAcc  #静止区間を除去した後のリストを返す

# %%
#連続する2サンプルの差分を取る関数
def calculate_differences_of_acceleration(ResultantAcc: list[float]) -> list[float]:
    #DifferenceAcc = [math.fabs(ResultantAcc[i + 1] * 100000 - ResultantAcc[i] * 100000) for i in range(len(ResultantAcc) - 1)]  #100000倍して誤差を取る
    DifferenceAcc = [math.fabs(ResultantAcc[i + 1] - ResultantAcc[i]) for i in range(len(ResultantAcc) - 1)]  #誤差を取る
    return DifferenceAcc

# %%
#入力された加速度の差分のリストからヒストグラムを作る関数（ビンの範囲が各加速度の差分データの最小値〜最大値）
def create_histogram2(DifferenceAcc_list: list[float]) -> np.histogram:
    DifferenceAcc_hist = np.zeros((len(DifferenceAcc_list), BINS), dtype=float)
    for i in range(len(DifferenceAcc_list)):
        min_value = min(DifferenceAcc_list[i])
        max_value = max(DifferenceAcc_list[i])
        #DifferenceAcc_hist[i], _ = np.histogram(DifferenceAcc_list[i], bins=BINS, range=(min_value, max_value)) #ヒストグラムを作成し、同じ数のビンで区切る
        DifferenceAcc_hist[i], _ = np.histogram(DifferenceAcc_list[i], bins=BINS, density=True) #ヒストグラムを作成し、同じ数のビンで区切る
    return DifferenceAcc_hist

# %%
#各加速度データをダウンサンプリングする関数
def resampling_Acc(originHz: int, newHz: int, AccX: list[float], AccY: list[float], AccZ: list[float], Hz: np.array) -> tuple[list[float], list[float], list[float], np.array]:
    i = 0   #カウンター変数

    while (Hz[i] == originHz):
        originlen = len(AccX[i])    #元々のデータの長さ
        sampling_factor = int(originlen * (newHz/originHz)) #ダウンサンプリングした後のデータの長さ
        newAccX = signal.resample(AccX[i], sampling_factor)    #データをダウンサンプリング
        newAccY = signal.resample(AccY[i], sampling_factor)    #データをダウンサンプリング
        newAccZ = signal.resample(AccZ[i], sampling_factor)    #データをダウンサンプリング
        AccX.append(newAccX)   #ダウンサンプリングデータを加速度データに追加
        AccY.append(newAccY)   #ダウンサンプリングデータを加速度データに追加
        AccZ.append(newAccZ)   #ダウンサンプリングデータを加速度データに追加
        Hz = np.append(Hz, newHz)   #ダウンサンプリングレートを追加
        i += 1

    return AccX, AccY, AccZ, Hz

# %%
path = "/content/drive/MyDrive/my_walk_data(100Hz15minutes)/"  #Google colab用
#path = "my_walk_data(100Hz15minutes)/"  #local用

# %%
#GPUを使うためのコマンド
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
#一連の流れ
Hz_and_filename = get_Hz_and_filename(path)
Hz_and_filename.sort(reverse=True)  #周波数の大きい順にソート
Hz, filename = divide_Hz_and_filename(Hz_and_filename)
Hz = np.array(Hz)

#使う変数を宣言
readAccX, readAccY, readAccZ = [], [], []   #データ読み込む用
AccX, AccY, AccZ = [], [], []
ResultantAcc = []
DifferenceAcc_list = []

#各データセットからデータを読み込み二次元配列に格納
for i in filename:
    readAccX, readAccY, readAccZ = get_acceleration(path+i)
    AccX.append(readAccX), AccY.append(readAccY), AccZ.append(readAccZ)

#各加速度データをダウンサンプリング
for i in range(9, 1, -1):
    AccX, AccY, AccZ, Hz = resampling_Acc(100, i * 10, AccX, AccY, AccZ, Hz)

#静止区間を除去
for i in range(len(Hz)):
    ResultantAcc.append(acc_to_remove_stationary_intervals(AccX[i], AccY[i], AccZ[i]))

# %%
#ヒストグラム作成
for i in range(len(ResultantAcc)):
    DifferenceAcc_list.append(calculate_differences_of_acceleration(ResultantAcc[i]))
DifferenceAcc_hist = create_histogram2(DifferenceAcc_list)

# %%
#グラフを表示する領域を，figオブジェクトとして作成。
fig = plt.figure(figsize = (9,6))
xl1 = "acceleration (0.1mG)"
yl1 = "frequency"

#グラフを描画するsubplot領域を作成。
ax1 = fig.add_subplot(3, 1, 1)
ax2 = fig.add_subplot(3, 1, 2)
ax3 = fig.add_subplot(3, 1, 3)

#各subplot領域にデータを渡す
ax1.hist(ResultantAcc[0], bins=BINS,density=True, range = (0, 40000), label="100 Hz")
ax2.hist(ResultantAcc[125], bins=BINS, density=True, range = (0, 40000), label="50 Hz")
ax3.hist(ResultantAcc[200], bins=BINS,density=True, range = (0, 40000), label="20 Hz")

#各subplotにxラベルを追加
ax1.set_xlabel(xl1)
ax2.set_xlabel(xl1)
ax3.set_xlabel(xl1)

#各subplotにyラベルを追加
ax1.set_ylabel(yl1)
ax2.set_ylabel(yl1)
ax3.set_ylabel(yl1)

# 凡例表示
ax1.legend(loc = 'upper right')
ax2.legend(loc = 'upper right')
ax3.legend(loc = 'upper right')

plt.show()

# %%
#入力データの標準化
scaler = StandardScaler()
# Fit the scaler to x_train
scaler.fit(DifferenceAcc_hist)
# Use the scaler to transform x_train and x_test
DifferenceAcc_hist = scaler.transform(DifferenceAcc_hist)

# %%
#transformer regression
#各種パラメータ
NUM_HEADS = 8
KEY_DIM = int(BINS/NUM_HEADS)
DROPOUT = 0.1
N = 1

# Define the input shape
input_shape = BINS
output_shape = 1

#形を定義(このモジュールは行列でないとダメっぽい)
inputs_encoder = layers.Input(shape=input_shape)
inputs_decoder = layers.Input(shape=output_shape)

# %%
#Encoderに対する入力の形状
x_encoder = layers.Reshape((10, int(BINS/10)))(inputs_encoder)

# %%
#Transformer Encoder Layer(BERT)
for i in range(N):
      #Multi-Head-Attention Layer
      attention_encoder = layers.MultiHeadAttention(num_heads=NUM_HEADS, key_dim=KEY_DIM, use_bias=True)(x_encoder, x_encoder, x_encoder)

      #Dropout Layer
      attention_encoder = layers.Dropout(rate=DROPOUT)(attention_encoder)
      #Add & Norm Layer
      attention_encoder = layers.LayerNormalization()(x_encoder + attention_encoder)

      #Feed-Forward-Network
      ffn_encoder = layers.Dense(int(BINS/10) * 4, use_bias=True, activation="relu")(attention_encoder)
      ffn_encoder = layers.Dense(int(BINS/10), use_bias=True)(ffn_encoder)

      #Dropout Layer
      ffn_encoder = layers.Dropout(rate=DROPOUT)(ffn_encoder)
      #Add & Norm Layer
      x_encoder = layers.LayerNormalization()(attention_encoder + ffn_encoder)

# %%
#only Encoder(Dense追加BERT)
x = layers.Flatten()(x_encoder)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.1)(x)
x = layers.Dense(64, activation="relu")(x)
x = layers.Dropout(0.1)(x)
outputs = layers.Dense(1, activation="relu")(x)
model = keras.Model(inputs=inputs_encoder, outputs=outputs)

# %%
# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.mean_squared_error,
    metrics=[keras.metrics.mean_squared_error],
)

# %%
#モデルの画像を出力
plot_model(model, show_shapes=True, show_layer_names=False)

# %%
mae = []
mse = []
r2 = []

# %%
for i in range(30):
  #only Encoder Transformer 試行用
  x_train, x_test, y_train, y_test = train_test_split(DifferenceAcc_hist, Hz, train_size = TRAIN_SIZE, shuffle = True)
  history = model.fit(x_train, y_train, batch_size=32, epochs=300, shuffle=True, validation_split=0.2)
  y_pred = tf.cast(tf.clip_by_value(model.predict(x_test), 20, 100), tf.int32)
  mae.append(mean_absolute_error(y_pred, y_test))
  mse.append(mean_squared_error(y_pred, y_test))
  r2.append(r2_score(y_pred, y_test))
  #aa = Hz.reshape(len(Hz),1)
  #diff = y_pred - aa
  #var.append(np.var(diff))
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# 5/5 [==============================] - 0s 28ms/step - loss: 17.1240 - mean_squared_error: 17.1240 - val_loss: 9.2488 - val_mean_squared_error: 9.2488
# Epoch 206/300
# 5/5 [==============================] - 0s 31ms/step - loss: 21.8199 - mean_squared_error: 21.8199 - val_loss: 14.2878 - val_mean_squared_error: 14.2878
# Epoch 207/300
# 5/5 [==============================] - 0s 27ms/step - loss: 16.5448 - mean_squared_error: 16.5448 - val_loss: 22.6911 - val_mean_squared_error: 22.6911
# Epoch 208/300
# 5/5 [==============================] - 0s 29ms/step - loss: 16.0953 - mean_squared_error: 16.0953 - val_loss: 16.7688 - val_mean_squared_error: 16.7688
# Epoch 209/300
# 5/5 [==============================] - 0s 26ms/step - loss: 20.0621 - mean_squared_error: 20.0621 - val_loss: 19.3707 - val_mean_squared_error: 19.3707
# Epoch 210/300
# 5/5 [==============================] - 0s 29ms/step - loss: 14.0840 - mean_squared_error: 14.0840 - val_loss: 14.3740 - val_mean_squared_error: 14.3740
# Epoch 211/300
# 5/5 [==============================] - 0s 29ms/step - loss: 17.0471 - mean_squared_error: 17.0471 - val_loss: 18.4691 - val_mean_squared_error: 18.4691
# Epoch 212/300
# 5/5 [==============================] - 0s 26ms/step - loss: 12.4263 - mean_squared_error: 12.4263 - val_loss: 13.6636 - val_mean_squared_error: 13.6636
# Epoch 213/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.0351 - mean_squared_error: 14.0351 - val_loss: 22.3837 - val_mean_squared_error: 22.3837
# Epoch 214/300
# 5/5 [==============================] - 0s 28ms/step - loss: 19.1921 - mean_squared_error: 19.1921 - val_loss: 14.1856 - val_mean_squared_error: 14.1856
# Epoch 215/300
# 5/5 [==============================] - 0s 29ms/step - loss: 16.5754 - mean_squared_error: 16.5754 - val_loss: 21.5032 - val_mean_squared_error: 21.5032
# Epoch 216/300
# 5/5 [==============================] - 0s 26ms/step - loss: 20.2556 - mean_squared_error: 20.2556 - val_loss: 12.1100 - val_mean_squared_error: 12.1100
# Epoch 217/300
# 5/5 [==============================] - 0s 27ms/step - loss: 13.5460 - mean_squared_error: 13.5460 - val_loss: 24.6704 - val_mean_squared_error: 24.6704
# Epoch 218/300
# 5/5 [==============================] - 0s 27ms/step - loss: 15.6214 - mean_squared_error: 15.6214 - val_loss: 18.2149 - val_mean_squared_error: 18.2149
# Epoch 219/300
# 5/5 [==============================] - 0s 27ms/step - loss: 15.7499 - mean_squared_error: 15.7499 - val_loss: 11.7287 - val_mean_squared_error: 11.7287
# Epoch 220/300
# 5/5 [==============================] - 0s 28ms/step - loss: 18.6529 - mean_squared_error: 18.6529 - val_loss: 37.3328 - val_mean_squared_error: 37.3328
# Epoch 221/300
# 5/5 [==============================] - 0s 28ms/step - loss: 22.1981 - mean_squared_error: 22.1981 - val_loss: 9.4723 - val_mean_squared_error: 9.4723
# Epoch 222/300
# 5/5 [==============================] - 0s 26ms/step - loss: 12.2629 - mean_squared_error: 12.2629 - val_loss: 27.0550 - val_mean_squared_error: 27.0550
# Epoch 223/300
# 5/5 [==============================] - 0s 27ms/step - loss: 17.4260 - mean_squared_error: 17.4260 - val_loss: 13.5759 - val_mean_squared_error: 13.5759
# Epoch 224/300
# 5/5 [==============================] - 0s 30ms/step - loss: 16.9995 - mean_squared_error: 16.9995 - val_loss: 14.2607 - val_mean_squared_error: 14.2607
# Epoch 225/300
# 5/5 [==============================] - 0s 27ms/step - loss: 21.0112 - mean_squared_error: 21.0112 - val_loss: 18.0343 - val_mean_squared_error: 18.0343
# Epoch 226/300
# 5/5 [==============================] - 0s 31ms/step - loss: 16.4597 - mean_squared_error: 16.4597 - val_loss: 14.4376 - val_mean_squared_error: 14.4376
# Epoch 227/300
# 5/5 [==============================] - 0s 30ms/step - loss: 14.9049 - mean_squared_error: 14.9049 - val_loss: 18.8447 - val_mean_squared_error: 18.8447
# Epoch 228/300
# 5/5 [==============================] - 0s 29ms/step - loss: 13.9961 - mean_squared_error: 13.9961 - val_loss: 20.4739 - val_mean_squared_error: 20.4739
# Epoch 229/300
# 5/5 [==============================] - 0s 27ms/step - loss: 17.0222 - mean_squared_error: 17.0222 - val_loss: 11.9422 - val_mean_squared_error: 11.9422
# Epoch 230/300
# 5/5 [==============================] - 0s 27ms/step - loss: 19.7028 - mean_squared_error: 19.7028 - val_loss: 20.6002 - val_mean_squared_error: 20.6002
# Epoch 231/300
# 5/5 [==============================] - 0s 27ms/step - loss: 20.2307 - mean_squared_error: 20.2307 - val_loss: 12.9548 - val_mean_squared_error: 12.9548
# Epoch 232/300
# 5/5 [==============================] - 0s 29ms/step - loss: 16.1410 - mean_squared_error: 16.1410 - val_loss: 19.8881 - val_mean_squared_error: 19.8881
# Epoch 233/300
# 5/5 [==============================] - 0s 28ms/step - loss: 15.0984 - mean_squared_error: 15.0984 - val_loss: 14.2347 - val_mean_squared_error: 14.2347
# Epoch 234/300
# 5/5 [==============================] - 0s 29ms/step - loss: 14.7262 - mean_squared_error: 14.7262 - val_loss: 12.4834 - val_mean_squared_error: 12.4834
# Epoch 235/300
# 5/5 [==============================] - 0s 27ms/step - loss: 17.9862 - mean_squared_error: 17.9862 - val_loss: 15.5153 - val_mean_squared_error: 15.5153
# Epoch 236/300
# 5/5 [==============================] - 0s 25ms/step - loss: 23.3113 - mean_squared_error: 23.3113 - val_loss: 10.7630 - val_mean_squared_error: 10.7630
# Epoch 237/300
# 5/5 [==============================] - 0s 25ms/step - loss: 14.1882 - mean_squared_error: 14.1882 - val_loss: 30.0026 - val_mean_squared_error: 30.0026
# Epoch 238/300
# 5/5 [==============================] - 0s 25ms/step - loss: 14.8763 - mean_squared_error: 14.8763 - val_loss: 8.6676 - val_mean_squared_error: 8.6676
# Epoch 239/300
# 5/5 [==============================] - 0s 26ms/step - loss: 18.1255 - mean_squared_error: 18.1255 - val_loss: 21.7201 - val_mean_squared_error: 21.7201
# Epoch 240/300
# 5/5 [==============================] - 0s 25ms/step - loss: 19.0647 - mean_squared_error: 19.0647 - val_loss: 8.9620 - val_mean_squared_error: 8.9620
# Epoch 241/300
# 5/5 [==============================] - 0s 27ms/step - loss: 12.9090 - mean_squared_error: 12.9090 - val_loss: 21.6651 - val_mean_squared_error: 21.6651
# Epoch 242/300
# 5/5 [==============================] - 0s 29ms/step - loss: 17.7912 - mean_squared_error: 17.7912 - val_loss: 12.6771 - val_mean_squared_error: 12.6771
# Epoch 243/300
# 5/5 [==============================] - 0s 27ms/step - loss: 18.8965 - mean_squared_error: 18.8965 - val_loss: 19.9168 - val_mean_squared_error: 19.9168
# Epoch 244/300
# 5/5 [==============================] - 0s 27ms/step - loss: 16.8201 - mean_squared_error: 16.8201 - val_loss: 16.1963 - val_mean_squared_error: 16.1963
# Epoch 245/300
# 5/5 [==============================] - 0s 27ms/step - loss: 11.9121 - mean_squared_error: 11.9121 - val_loss: 15.5774 - val_mean_squared_error: 15.5774
# Epoch 246/300
# 5/5 [==============================] - 0s 28ms/step - loss: 11.9390 - mean_squared_error: 11.9390 - val_loss: 20.5645 - val_mean_squared_error: 20.5645
# Epoch 247/300
# 5/5 [==============================] - 0s 27ms/step - loss: 20.4051 - mean_squared_error: 20.4051 - val_loss: 10.3782 - val_mean_squared_error: 10.3782
# Epoch 248/300
# 5/5 [==============================] - 0s 29ms/step - loss: 12.9107 - mean_squared_error: 12.9107 - val_loss: 18.0183 - val_mean_squared_error: 18.0183
# Epoch 249/300
# 5/5 [==============================] - 0s 29ms/step - loss: 15.8227 - mean_squared_error: 15.8227 - val_loss: 13.0935 - val_mean_squared_error: 13.0935
# Epoch 250/300
# 5/5 [==============================] - 0s 29ms/step - loss: 13.0995 - mean_squared_error: 13.0995 - val_loss: 9.8881 - val_mean_squared_error: 9.8881
# Epoch 251/300
# 5/5 [==============================] - 0s 26ms/step - loss: 19.5439 - mean_squared_error: 19.5439 - val_loss: 10.8234 - val_mean_squared_error: 10.8234
# Epoch 252/300
# 5/5 [==============================] - 0s 27ms/step - loss: 16.0565 - mean_squared_error: 16.0565 - val_loss: 21.2573 - val_mean_squared_error: 21.2573
# Epoch 253/300
# 5/5 [==============================] - 0s 25ms/step - loss: 14.1586 - mean_squared_error: 14.1586 - val_loss: 14.6548 - val_mean_squared_error: 14.6548
# Epoch 254/300
# 5/5 [==============================] - 0s 23ms/step - loss: 11.9083 - mean_squared_error: 11.9083 - val_loss: 12.4951 - val_mean_squared_error: 12.4951
# Epoch 255/300
# 5/5 [==============================] - 0s 24ms/step - loss: 17.1562 - mean_squared_error: 17.1562 - val_loss: 23.0574 - val_mean_squared_error: 23.0574
# Epoch 256/300
# 5/5 [==============================] - 0s 26ms/step - loss: 13.2407 - mean_squared_error: 13.2407 - val_loss: 10.4233 - val_mean_squared_error: 10.4233
# Epoch 257/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.3033 - mean_squared_error: 14.3033 - val_loss: 28.1770 - val_mean_squared_error: 28.1770
# Epoch 258/300
# 5/5 [==============================] - 0s 29ms/step - loss: 14.4276 - mean_squared_error: 14.4276 - val_loss: 11.3604 - val_mean_squared_error: 11.3604
# Epoch 259/300
# 5/5 [==============================] - 0s 27ms/step - loss: 12.6381 - mean_squared_error: 12.6381 - val_loss: 20.9334 - val_mean_squared_error: 20.9334
# Epoch 260/300
# 5/5 [==============================] - 0s 26ms/step - loss: 13.4829 - mean_squared_error: 13.4829 - val_loss: 21.6925 - val_mean_squared_error: 21.6925
# Epoch 261/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.2868 - mean_squared_error: 14.2868 - val_loss: 11.4164 - val_mean_squared_error: 11.4164
# Epoch 262/300
# 5/5 [==============================] - 0s 26ms/step - loss: 12.5634 - mean_squared_error: 12.5634 - val_loss: 16.2892 - val_mean_squared_error: 16.2892
# Epoch 263/300
# 5/5 [==============================] - 0s 28ms/step - loss: 16.9486 - mean_squared_error: 16.9486 - val_loss: 12.6071 - val_mean_squared_error: 12.6071
# Epoch 264/300
# 5/5 [==============================] - 0s 26ms/step - loss: 17.5661 - mean_squared_error: 17.5661 - val_loss: 17.7706 - val_mean_squared_error: 17.7706
# Epoch 265/300
# 5/5 [==============================] - 0s 27ms/step - loss: 22.6604 - mean_squared_error: 22.6604 - val_loss: 14.6777 - val_mean_squared_error: 14.6777
# Epoch 266/300
# 5/5 [==============================] - 0s 28ms/step - loss: 11.8510 - mean_squared_error: 11.8510 - val_loss: 19.3757 - val_mean_squared_error: 19.3757
# Epoch 267/300
# 5/5 [==============================] - 0s 26ms/step - loss: 11.7565 - mean_squared_error: 11.7565 - val_loss: 19.7599 - val_mean_squared_error: 19.7599
# Epoch 268/300
# 5/5 [==============================] - 0s 30ms/step - loss: 13.7437 - mean_squared_error: 13.7437 - val_loss: 25.3194 - val_mean_squared_error: 25.3194
# Epoch 269/300
# 5/5 [==============================] - 0s 26ms/step - loss: 15.7818 - mean_squared_error: 15.7818 - val_loss: 11.5623 - val_mean_squared_error: 11.5623
# Epoch 270/300
# 5/5 [==============================] - 0s 24ms/step - loss: 15.8683 - mean_squared_error: 15.8683 - val_loss: 23.7682 - val_mean_squared_error: 23.7682
# Epoch 271/300
# 5/5 [==============================] - 0s 25ms/step - loss: 15.6044 - mean_squared_error: 15.6044 - val_loss: 13.7073 - val_mean_squared_error: 13.7073
# Epoch 272/300
# 5/5 [==============================] - 0s 26ms/step - loss: 15.0044 - mean_squared_error: 15.0044 - val_loss: 11.9454 - val_mean_squared_error: 11.9454
# Epoch 273/300
# 5/5 [==============================] - 0s 25ms/step - loss: 13.9922 - mean_squared_error: 13.9922 - val_loss: 13.8440 - val_mean_squared_error: 13.8440
# Epoch 274/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.4322 - mean_squared_error: 14.4322 - val_loss: 14.6923 - val_mean_squared_error: 14.6923
# Epoch 275/300
# 5/5 [==============================] - 0s 26ms/step - loss: 13.9204 - mean_squared_error: 13.9204 - val_loss: 12.3428 - val_mean_squared_error: 12.3428
# Epoch 276/300
# 5/5 [==============================] - 0s 26ms/step - loss: 11.4523 - mean_squared_error: 11.4523 - val_loss: 20.5701 - val_mean_squared_error: 20.5701
# Epoch 277/300
# 5/5 [==============================] - 0s 34ms/step - loss: 19.8733 - mean_squared_error: 19.8733 - val_loss: 17.7037 - val_mean_squared_error: 17.7037
# Epoch 278/300
# 5/5 [==============================] - 0s 30ms/step - loss: 17.3544 - mean_squared_error: 17.3544 - val_loss: 16.6826 - val_mean_squared_error: 16.6826
# Epoch 279/300
# 5/5 [==============================] - 0s 40ms/step - loss: 18.2258 - mean_squared_error: 18.2258 - val_loss: 14.1909 - val_mean_squared_error: 14.1909
# Epoch 280/300
300
# 5/5 [==============================] - 0s 26ms/step - loss: 17.9302 - mean_squared_error: 17.9302 - val_loss: 10.6815 - val_mean_squared_error: 10.6815
# Epoch 60/300
# 5/5 [==============================] - 0s 26ms/step - loss: 20.0365 - mean_squared_error: 20.0365 - val_loss: 14.7542 - val_mean_squared_error: 14.7542
# Epoch 61/300
# 5/5 [==============================] - 0s 24ms/step - loss: 18.1924 - mean_squared_error: 18.1924 - val_loss: 10.5003 - val_mean_squared_error: 10.5003
# Epoch 62/300
# 5/5 [==============================] - 0s 25ms/step - loss: 14.1130 - mean_squared_error: 14.1130 - val_loss: 15.1828 - val_mean_squared_error: 15.1828
# Epoch 63/300
# 5/5 [==============================] - 0s 28ms/step - loss: 15.4352 - mean_squared_error: 15.4352 - val_loss: 9.4334 - val_mean_squared_error: 9.4334
# Epoch 64/300
# 5/5 [==============================] - 0s 26ms/step - loss: 16.2883 - mean_squared_error: 16.2883 - val_loss: 18.4922 - val_mean_squared_error: 18.4922
# Epoch 65/300
# 5/5 [==============================] - 0s 28ms/step - loss: 18.3139 - mean_squared_error: 18.3139 - val_loss: 7.3174 - val_mean_squared_error: 7.3174
# Epoch 66/300
# 5/5 [==============================] - 0s 26ms/step - loss: 15.7636 - mean_squared_error: 15.7636 - val_loss: 25.6829 - val_mean_squared_error: 25.6829
# Epoch 67/300
# 5/5 [==============================] - 0s 27ms/step - loss: 18.7123 - mean_squared_error: 18.7123 - val_loss: 15.8788 - val_mean_squared_error: 15.8788
# Epoch 68/300
# 5/5 [==============================] - 0s 28ms/step - loss: 18.1811 - mean_squared_error: 18.1811 - val_loss: 17.5189 - val_mean_squared_error: 17.5189
# Epoch 69/300
# 5/5 [==============================] - 0s 28ms/step - loss: 24.1538 - mean_squared_error: 24.1538 - val_loss: 8.0509 - val_mean_squared_error: 8.0509
# Epoch 70/300
# 5/5 [==============================] - 0s 25ms/step - loss: 17.5080 - mean_squared_error: 17.5080 - val_loss: 24.9221 - val_mean_squared_error: 24.9221
# Epoch 71/300
# 5/5 [==============================] - 0s 26ms/step - loss: 18.6478 - mean_squared_error: 18.6478 - val_loss: 8.8785 - val_mean_squared_error: 8.8785
# Epoch 72/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.2997 - mean_squared_error: 14.2997 - val_loss: 31.8460 - val_mean_squared_error: 31.8460
# Epoch 73/300
# 5/5 [==============================] - 0s 28ms/step - loss: 25.8970 - mean_squared_error: 25.8970 - val_loss: 8.4020 - val_mean_squared_error: 8.4020
# Epoch 74/300
# 5/5 [==============================] - 0s 25ms/step - loss: 15.7993 - mean_squared_error: 15.7993 - val_loss: 15.8019 - val_mean_squared_error: 15.8019
# Epoch 75/300
# 5/5 [==============================] - 0s 30ms/step - loss: 21.6473 - mean_squared_error: 21.6473 - val_loss: 12.3894 - val_mean_squared_error: 12.3894
# Epoch 76/300
# 5/5 [==============================] - 0s 26ms/step - loss: 15.3506 - mean_squared_error: 15.3506 - val_loss: 14.0034 - val_mean_squared_error: 14.0034
# Epoch 77/300
# 5/5 [==============================] - 0s 30ms/step - loss: 18.1898 - mean_squared_error: 18.1898 - val_loss: 20.5699 - val_mean_squared_error: 20.5699
# Epoch 78/300
# 5/5 [==============================] - 0s 36ms/step - loss: 16.6468 - mean_squared_error: 16.6468 - val_loss: 16.3460 - val_mean_squared_error: 16.3460
# Epoch 79/300
# 5/5 [==============================] - 0s 31ms/step - loss: 16.6829 - mean_squared_error: 16.6829 - val_loss: 13.9731 - val_mean_squared_error: 13.9731
# Epoch 80/300
# 5/5 [==============================] - 0s 30ms/step - loss: 15.2815 - mean_squared_error: 15.2815 - val_loss: 12.3563 - val_mean_squared_error: 12.3563
# Epoch 81/300
# 5/5 [==============================] - 0s 28ms/step - loss: 11
300
# 5/5 [==============================] - 0s 25ms/step - loss: 17.8453 - mean_squared_error: 17.8453 - val_loss: 5.5093 - val_mean_squared_error: 5.5093
# Epoch 120/300
# 5/5 [==============================] - 0s 25ms/step - loss: 20.8057 - mean_squared_error: 20.8057 - val_loss: 20.7638 - val_mean_squared_error: 20.7638
# Epoch 121/300
# 5/5 [==============================] - 0s 29ms/step - loss: 17.6547 - mean_squared_error: 17.6547 - val_loss: 15.5337 - val_mean_squared_error: 15.5337
# Epoch 122/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.7191 - mean_squared_error: 14.7191 - val_loss: 14.2050 - val_mean_squared_error: 14.2050
# Epoch 123/300
# 5/5 [==============================] - 0s 25ms/step - loss: 17.8136 - mean_squared_error: 17.8136 - val_loss: 15.4871 - val_mean_squared_error: 15.4871
# Epoch 124/300
# 5/5 [==============================] - 0s 27ms/step - loss: 16.0295 - mean_squared_error: 16.0295 - val_loss: 9.5799 - val_mean_squared_error: 9.5799
# Epoch 125/300
# 5/5 [==============================] - 0s 29ms/step - loss: 19.8249 - mean_squared_error: 19.8249 - val_loss: 15.5468 - val_mean_squared_error: 15.5468
# Epoch 126/300
# 5/5 [==============================] - 0s 25ms/step - loss: 14.5837 - mean_squared_error: 14.5837 - val_loss: 5.8513 - val_mean_squared_error: 5.8513
# Epoch 127/300
# 5/5 [==============================] - 0s 28ms/step - loss: 17.4289 - mean_squared_error: 17.4289 - val_loss: 15.9117 - val_mean_squared_error: 15.9117
# Epoch 128/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.4227 - mean_squared_error: 14.4227 - val_loss: 10.1683 - val_mean_squared_error: 10.1683
# Epoch 129/300
# 5/5 [==============================] - 0s 26ms/step - loss: 15.0796 - mean_squared_error: 15.0796 - val_loss: 14.2585 - val_mean_squared_error: 14.2585
# Epoch 130/300
# 5/5 [==============================] - 0s 29ms/step - loss: 14.3293 - mean_squared_error: 14.3293 - val_loss: 19.5732 - val_mean_squared_error: 19.5732
# Epoch 131/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.6763 - mean_squared_error: 14.6763 - val_loss: 9.1102 - val_mean_squared_error: 9.1102
# Epoch 132/300
# 5/5 [==============================] - 0s 27ms/step - loss: 14.1079 - mean_squared_error: 14.1079 - val_loss: 20.8074 - val_mean_squared_error: 20.8074
# Epoch 133/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.0559 - mean_squared_error: 14.0559 - val_loss: 8.2161 - val_mean_squared_error: 8.2161
# Epoch 134/300
# 5/5 [==============================] - 0s 25ms/step - loss: 17.7813 - mean_squared_error: 17.7813 - val_loss: 11.1600 - val_mean_squared_error: 11.1600
# Epoch 135/300
# 5/5 [==============================] - 0s 27ms/step - loss: 14.8441 - mean_squared_error: 14.8441 - val_loss: 19.3425 - val_mean_squared_error: 19.3425
# Epoch 136/300
# 5/5 [==============================] - 0s 27ms/step - loss: 16.6608 - mean_squared_error: 16.6608 - val_loss: 10.7650 - val_mean_squared_error: 10.7650
# Epoch 137/300
# 5/5 [==============================] - 0s 28ms/step - loss: 13.1661 - mean_squared_error: 13.1661 - val_loss: 11.3198 - val_mean_squared_error: 11.3198
# Epoch 138/300
# 5/5 [==============================] - 0s 24ms/step - loss: 18.9764 - mean_squared_error: 18.9764 - val_loss: 7.2355 - val_mean_squared_error: 7.2355
# Epoch 139/300
# 5/5 [==============================] - 0s 27ms/step - loss: 16.2703 - mean_squared_error: 16.2703 - val_loss: 8.3938 - val_mean_squared_error: 8.3938
# Epoch 140/300
# 5/5 [==============================] - 0s 29ms/step - loss: 13.7445 - mean_squared_error: 13.7445 - val_loss: 15.9457 - val_mean_squared_error: 15.9457
# Epoch 141/300
# 5/5 [==============================] - 0s 26ms/step - loss: 19.7802 - mean_squared_error: 19.7802 - val_loss: 10.1155 - val_mean_squared_error: 10.1155
# Epoch 142/300
# 5/5 [==============================] - 0s 24ms/step - loss: 15.5609 - mean_squared_error: 15.5609 - val_loss: 13.1222 - val_mean_squared_error: 13.1222
# Epoch 143/300
# 5/5 [==============================] - 0s 25ms/step - loss: 15.9484 - mean_squared_error: 15.9484 - val_loss: 18.2983 - val_mean_squared_error: 18.2983
# Epoch 144/300
# 5/5 [==============================] - 0s 27ms/step - loss: 14.5019 - mean_squared_error: 14.5019 - val_loss: 13.5514 - val_mean_squared_error: 13.5514
# Epoch 145/300
# 5/5 [==============================] - 0s 27ms/step - loss: 14.7006 - mean_squared_error: 14.7006 - val_loss: 12.2596 - val_mean_squared_error: 12.2596
# Epoch 146/300
# 5/5 [==============================] - 0s 25ms/step - loss: 14.8788 - mean_squared_error: 14.8788 - val_loss: 10.1365 - val_mean_squared_error: 10.1365
# Epoch 147/300
# 5/5 [==============================] - 0s 29ms/step - loss: 18.4464 - mean_squared_error: 18.4464 - val_loss: 12.5344 - val_mean_squared_error: 12.5344
# Epoch 148/300
# 5/5 [==============================] - 0s 30ms/step - loss: 22.1511 - mean_squared_error: 22.1511 - val_loss: 8.3568 - val_mean_squared_error: 8.3568
# Epoch 149/300
# 5/5 [==============================] - 0s 25ms/step - loss: 17.8636 - mean_squared_error: 17.8636 - val_loss: 6.7783 - val_mean_squared_error: 6.7783
# Epoch 150/300
# 5/5 [==============================] - 0s 27ms/step - loss: 14.5790 - mean_squared_error: 14.5790 - val_loss: 14.6435 - val_mean_squared_error: 14.6435
# Epoch 151/300
# 5/5 [==============================] - 0s 27ms/step - loss: 17.6514 - mean_squared_error: 17.6514 - val_loss: 12.8816 - val_mean_squared_error: 12.8816
# Epoch 152/300
# 5/5 [==============================] - 0s 26ms/step - loss: 18.1293 - mean_squared_error: 18.1293 - val_loss: 9.4195 - val_mean_squared_error: 9.4195
# Epoch 153/300
# 5/5 [==============================] - 0s 25ms/step - loss: 16.8783 - mean_squared_error: 16.8783 - val_loss: 19.8794 - val_mean_squared_error: 19.8794
# Epoch 154/300
# 5/5 [==============================] - 0s 27ms/step - loss: 13.3116 - mean_squared_error: 13.3116 - val_loss: 6.6987 - val_mean_squared_error: 6.6987
# Epoch 155/300
# 5/5 [==============================] - 0s 28ms/step - loss: 15.5351 - mean_squared_error: 15.5351 - val_loss: 13.2162 - val_mean_squared_error: 13.2162
# Epoch 156/300
# 5/5 [==============================] - 0s 28ms/step - loss: 17.1005 - mean_squared_error: 17.1005 - val_loss: 11.8605 - val_mean_squared_error: 11.8605
# Epoch 157/300
# 5/5 [==============================] - 0s 25ms/step - loss: 15.8998 - mean_squared_error: 15.8998 - val_loss: 6.5957 - val_mean_squared_error: 6.5957
# Epoch 158/300
# 5/5 [==============================] - 0s 25ms/step - loss: 18.9676 - mean_squared_error: 18.9676 - val_loss: 24.2958 - val_mean_squared_error: 24.2958
# Epoch 159/300
# 5/5 [==============================] - 0s 27ms/step - loss: 18.1103 - mean_squared_error: 18.1103 - val_loss: 9.4044 - val_mean_squared_error: 9.4044
# Epoch 160/300
# 5/5 [==============================] - 0s 27ms/step - loss: 17.2627 - mean_squared_error: 17.2627 - val_loss: 6.7108 - val_mean_squared_error: 6.7108
# Epoch 161/300
# 5/5 [==============================] - 0s 25ms/step - loss: 12.6313 - mean_squared_error: 12.6313 - val_loss: 18.1542 - val_mean_squared_error: 18.1542
# Epoch 162/300
# 5/5 [==============================] - 0s 24ms/step - loss: 16.7122 - mean_squared_error: 16.7122 - val_loss: 7.1102 - val_mean_squared_error: 7.1102
# Epoch 163/300
# 5/5 [==============================] - 0s 26ms/step - loss: 21.4678 - mean_squared_error: 21.4678 - val_loss: 10.3704 - val_mean_squared_error: 10.3704
# Epoch 164/300
# 5/5 [==============================] - 0s 27ms/step - loss: 13.0416 - mean_squared_error: 13.0416 - val_loss: 8.9952 - val_mean_squared_error: 8.9952
# Epoch 165/300
# 5/5 [==============================] - 0s 28ms/step - loss: 18.7552 - mean_squared_error: 18.7552 - val_loss: 11.5803 - val_mean_squared_error: 11.5803
# Epoch 166/300
# 5/5 [==============================] - 0s 26ms/step - loss: 18.8083 - mean_squared_error: 18.8083 - val_loss: 6.1195 - val_mean_squared_error: 6.1195
# Epoch 167/300
# 5/5 [==============================] - 0s 25ms/step - loss: 20.0110 - mean_squared_error: 20.0110 - val_loss: 15.7832 - val_mean_squared_error: 15.7832
# Epoch 168/300
# 5/5 [==============================] - 0s 26ms/step - loss: 13.1410 - mean_squared_error: 13.1410 - val_loss: 7.1024 - val_mean_squared_error: 7.1024
# Epoch 169/300
# 5/5 [==============================] - 0s 25ms/step - loss: 16.9214 - mean_squared_error: 16.9214 - val_loss: 24.9637 - val_mean_squared_error: 24.9637
# Epoch 170/300
# 5/5 [==============================] - 0s 27ms/step - loss: 22.4137 - mean_squared_error: 22.4137 - val_loss: 15.4294 - val_mean_squared_error: 15.4294
# Epoch 171/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.7797 - mean_squared_error: 14.7797 - val_loss: 11.2421 - val_mean_squared_error: 11.2421
# Epoch 172/300
# 5/5 [==============================] - 0s 26ms/step - loss: 11.2634 - mean_squared_error: 11.2634 - val_loss: 11.5471 - val_mean_squared_error: 11.5471
# Epoch 173/300
# 5/5 [==============================] - 0s 28ms/step - loss: 12.3485 - mean_squared_error: 12.3485 - val_loss: 11.4273 - val_mean_squared_error: 11.4273
# Epoch 174/300
# 5/5 [==============================] - 0s 28ms/step - loss: 12.5819 - mean_squared_error: 12.5819 - val_loss: 11.2409 - val_mean_squared_error: 11.2409
# Epoch 175/300
# 5/5 [==============================] - 0s 26ms/step - loss: 13.9194 - mean_squared_error: 13.9194 - val_loss: 23.7443 - val_mean_squared_error: 23.7443
# Epoch 176/300
# 5/5 [==============================] - 0s 26ms/step - loss: 17.2205 - mean_squared_error: 17.2205 - val_loss: 7.5488 - val_mean_squared_error: 7.5488
# Epoch 177/300
# 5/5 [==============================] - 0s 26ms/step - loss: 12.8240 - mean_squared_error: 12.8240 - val_loss: 18.0520 - val_mean_squared_error: 18.0520
# Epoch 178/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.2073 - mean_squared_error: 14.2073 - val_loss: 8.1573 - val_mean_squared_error: 8.1573
# Epoch 179/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.9207 - mean_squared_error: 14.9207 - val_loss: 7.4053 - val_mean_squared_error: 7.4053
# Epoch 180/300
# 5/5 [==============================] - 0s 30ms/step - loss: 13.1368 - mean_squared_error: 13.1368 - val_loss: 12.8189 - val_mean_squared_error: 12.8189
# Epoch 181/300
# 5/5 [==============================] - 0s 27ms/step - loss: 14.1481 - mean_squared_error: 14.1481 - val_loss: 14.8562 - val_mean_squared_error: 14.8562
# Epoch 182/300
# 5/5 [==============================] - 0s 27ms/step - loss: 12.9929 - mean_squared_error: 12.9929 - val_loss: 4.9383 - val_mean_squared_error: 4.9383
# Epoch 183/300
# 5/5 [==============================] - 0s 27ms/step - loss: 16.2705 - mean_squared_error: 16.2705 - val_loss: 23.0418 - val_mean_squared_error: 23.0418
# Epoch 184/300
# 5/5 [==============================] - 0s 28ms/step - loss: 17.4178 - mean_squared_error: 17.4178 - val_loss: 5.5799 - val_mean_squared_error: 5.5799
# Epoch 185/300
# 5/5 [==============================] - 0s 27ms/step - loss: 14.0575 - mean_squared_error: 14.0575 - val_loss: 15.2209 - val_mean_squared_error: 15.2209
# Epoch 186/300
# 5/5 [==============================] - 0s 31ms/step - loss: 13.3364 - mean_squared_error: 13.3364 - val_loss: 18.4380 - val_mean_squared_error: 18.4380
# Epoch 187/300
# 5/5 [==============================] - 0s 35ms/step - loss: 21.4600 - mean_squared_error: 21.4600 - val_loss: 14.6661 - val_mean_squared_error: 14.6661
# Epoch 188/300
# 5/5 [==============================] - 0s 37ms/step - loss: 20.2155 - mean_squared_error: 20.2155 - val_loss: 13.8256 - val_mean_squared_error: 13.8256
# Epoch 189/300
# 5/5 [==============================] - 0s 39ms/step - loss: 12.6807 - mean_squared_error: 12.6807 - val_loss: 5.2969 - val_mean_squared_error: 5.2969
# Epoch 190/300
# 5/5 [==============================] - 0s 33ms/step - loss: 12.2722 - mean_squared_error: 12.2722 - val_loss: 15.8249 - val_mean_squared_error: 15.8249
# Epoch 191/300
# 5/5 [==============================] - 0s 34ms/step - loss: 14.3701 - mean_squared_error: 14.3701 - val_loss: 10.9589 - val_mean_squared_error: 10.9589
# Epoch 192/300
# 5/5 [==============================] - 0s 37ms/step - loss: 14.2701 - mean_squared_error: 14.2701 - val_loss: 12.2426 - val_mean_squared_error: 12.2426
# Epoch 193/300
# 5/5 [==============================] - 0s 38ms/step - loss: 12.5444 - mean_squared_error: 12.5444 - val_loss: 14.1128 - val_mean_squared_error: 14.1128
# Epoch 194/300
# 5/5 [==============================] - 0s 34ms/step - loss: 12.9233 - mean_squared_error: 12.9233 - val_loss: 12.0528 - val_mean_squared_error: 12.0528
# Epoch 195/300
# ...
# Epoch 205/300
# 5/5 [==============================] - 0s 26ms/step - loss: 15.3078 - mean_squared_error: 15.3078 - val_loss: 29.1844 - val_mean_squared_error: 29.1844
# Epoch 206/300
# 5/5 [==============================] - 0s 27ms/step - loss: 13.1998 - mean_squared_error: 13.1998 - val_loss: 13.5757 - val_mean_squared_error: 13.5757
# Epoch 207/300
# 5/5 [==============================] - 0s 26ms/step - loss: 11.3319 - mean_squared_error: 11.3319 - val_loss: 17.1543 - val_mean_squared_error: 17.1543
# Epoch 208/300
# 5/5 [==============================] - 0s 29ms/step - loss: 13.0562 - mean_squared_error: 13.0562 - val_loss: 18.2569 - val_mean_squared_error: 18.2569
# Epoch 209/300
# 5/5 [==============================] - 0s 25ms/step - loss: 15.9634 - mean_squared_error: 15.9634 - val_loss: 8.4600 - val_mean_squared_error: 8.4600
# Epoch 210/300
# 5/5 [==============================] - 0s 25ms/step - loss: 15.2362 - mean_squared_error: 15.2362 - val_loss: 22.7685 - val_mean_squared_error: 22.7685
# Epoch 211/300
# 5/5 [==============================] - 0s 26ms/step - loss: 11.9414 - mean_squared_error: 11.9414 - val_loss: 12.5668 - val_mean_squared_error: 12.5668
# Epoch 212/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.7990 - mean_squared_error: 14.7990 - val_loss: 24.9394 - val_mean_squared_error: 24.9394
# Epoch 213/300
# 5/5 [==============================] - 0s 27ms/step - loss: 14.7291 - mean_squared_error: 14.7291 - val_loss: 7.2751 - val_mean_squared_error: 7.2751
# Epoch 214/300
# 5/5 [==============================] - 0s 24ms/step - loss: 17.0472 - mean_squared_error: 17.0472 - val_loss: 18.4826 - val_mean_squared_error: 18.4826
# Epoch 215/300
# 5/5 [==============================] - 0s 24ms/step - loss: 12.2875 - mean_squared_error: 12.2875 - val_loss: 18.1627 - val_mean_squared_error: 18.1627
# Epoch 216/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.2097 - mean_squared_error: 14.2097 - val_loss: 20.4628 - val_mean_squared_error: 20.4628
# Epoch 217/300
# 5/5 [==============================] - 0s 26ms/step - loss: 18.0251 - mean_squared_error: 18.0251 - val_loss: 9.0652 - val_mean_squared_error: 9.0652
# Epoch 218/300
# 5/5 [==============================] - 0s 27ms/step - loss: 13.4708 - mean_squared_error: 13.4708 - val_loss: 26.4716 - val_mean_squared_error: 26.4716
# Epoch 219/300
# 5/5 [==============================] - 0s 27ms/step - loss: 13.8003 - mean_squared_error: 13.8003 - val_loss: 11.2902 - val_mean_squared_error: 11.2902
# Epoch 220/300
# 5/5 [==============================] - 0s 26ms/step - loss: 13.9999 - mean_squared_error: 13.9999 - val_loss: 15.6345 - val_mean_squared_error: 15.6345
# Epoch 221/300
# 5/5 [==============================] - 0s 28ms/step - loss: 15.4083 - mean_squared_error: 15.4083 - val_loss: 10.7907 - val_mean_squared_error: 10.7907
# Epoch 222/300
# 5/5 [==============================] - 0s 28ms/step - loss: 11
300
# 5/5 [==============================] - 0s 28ms/step - loss: 13.1487 - mean_squared_error: 13.1487 - val_loss: 6.6900 - val_mean_squared_error: 6.6900
# Epoch 283/300
# 5/5 [==============================] - 0s 29ms/step - loss: 12.5951 - mean_squared_error: 12.5951 - val_loss: 25.6065 - val_mean_squared_error: 25.6065
# Epoch 284/300
# 5/5 [==============================] - 0s 28ms/step - loss: 13.8444 - mean_squared_error: 13.8444 - val_loss: 7.9837 - val_mean_squared_error: 7.9837
# Epoch 285/300
# 5/5 [==============================] - 0s 29ms/step - loss: 10.4866 - mean_squared_error: 10.4866 - val_loss: 21.6238 - val_mean_squared_error: 21.6238
# Epoch 286/300
# 5/5 [==============================] - 0s 28ms/step - loss: 13.9399 - mean_squared_error: 13.9399 - val_loss: 13.8876 - val_mean_squared_error: 13.8876
# Epoch 287/300
# 5/5 [==============================] - 0s 28ms/step - loss: 14.2082 - mean_squared_error: 14.2082 - val_loss: 6.9282 - val_mean_squared_error: 6.9282
# Epoch 288/300
# 5/5 [==============================] - 0s 26ms/step - loss: 14.0249 - mean_squared_error: 14.0249 - val_loss: 23.5452 - val_mean_squared_error: 23.5452
# Epoch 289/300
# 5/5 [==============================] - 0s 27ms/step - loss: 13.5754 - mean_squared_error: 13.5754 - val_loss: 8.8497 - val_mean_squared_error: 8.8497
# Epoch 290/300
# 5/5 [==============================] - 0s 27ms/step - loss: 11.7061 - mean_squared_error: 11.7061 - val_loss: 15.7041 - val_mean_squared_error: 15.7041
# Epoch 291/300
# 5/5 [==============================] - 0s 28ms/step - loss: 11.8253 - mean_squared_error: 11.8253 - val_loss: 20.7874 - val_mean_squared_error: 20.7874
# Epoch 292/300
# 5/5 [==============================] - 0s 29ms/step - loss: 10.3139 - mean_squared_error: 10.3139 - val_loss: 9.0103 - val_mean_squared_error: 9.0103
# Epoch 293/300
# 5/5 [==============================] - 0s 25ms/step - loss: 10.1213 - mean_squared_error: 10.1213 - val_loss: 29.9879 - val_mean_squared_error: 29.9879
# Epoch 294/300
# 5/5 [==============================] - 0s 29ms/step - loss: 15.2258 - mean_squared_error: 15.2258 - val_loss: 9.5410 - val_mean_squared_error: 9.5410
# Epoch 295/300
# 5/5 [==============================] - 0s 28ms/step - loss: 12.9598 - mean_squared_error: 12.9598 - val_loss: 24.8273 - val_mean_squared_error: 24.8273
# Epoch 296/300
# 5/5 [==============================] - 0s 27ms/step - loss: 17.1866 - mean_squared_error: 17.1866 - val_loss: 19.0892 - val_mean_squared_error: 19.0892
# Epoch 297/300
# 5/5 [==============================] - 0s 29ms/step - loss: 17.3775 - mean_squared_error: 17.3775 - val_loss: 6.0898 - val_mean_squared_error: 6.0898
# Epoch 298/300
# 5/5 [==============================] - 0s 25ms/step - loss: 15.0603 - mean_squared_error: 15.0603 - val_loss: 32.7135 - val_mean_squared_error: 32.7135
# Epoch 299/300
# 5/5 [==============================] - 0s 27ms/step - loss: 15.1039 - mean_squared_error: 15.1039 - val_loss: 6.5507 - val_mean_squared_error: 6.5507
# Epoch 300/300
# 5/5 [==============================] - 0s 28ms/step - loss: 20.6716 - mean_squared_error: 20.6716 - val_loss: 27.1097 - val_mean_squared_error: 27.1097

# %%
mae
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-71e26892b380> in <cell line: 1>()
# ----> 1 mae
#
# NameError: name 'mae' is not defined

# %%
mse

# %%
r2
